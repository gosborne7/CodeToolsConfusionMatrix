# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
# Set random seed
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
  tf.keras.layers.Dense(10, activation="softmax")
])

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(), # different loss function for multiclass classifcation
                 optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                 metrics=["accuracy"])

# %%
history = model.fit(train_images,
                       train_labels,
                       epochs=40,
                       validation_data=(test_images, test_labels))
# Out:
# Epoch 1/40
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.8422 - accuracy: 0.6923 - val_loss: 0.5536 - val_accuracy: 0.8087
# Epoch 2/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5156 - accuracy: 0.8204 - val_loss: 0.5060 - val_accuracy: 0.8248
# Epoch 3/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4752 - accuracy: 0.8331 - val_loss: 0.4947 - val_accuracy: 0.8237
# Epoch 4/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4470 - accuracy: 0.8437 - val_loss: 0.4747 - val_accuracy: 0.8277
# Epoch 5/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4330 - accuracy: 0.8469 - val_loss: 0.4810 - val_accuracy: 0.8239
# Epoch 6/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4203 - accuracy: 0.8498 - val_loss: 0.4781 - val_accuracy: 0.8291
# Epoch 7/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4121 - accuracy: 0.8538 - val_loss: 0.4570 - val_accuracy: 0.8404
# Epoch 8/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4058 - accuracy: 0.8556 - val_loss: 0.4346 - val_accuracy: 0.8467
# Epoch 9/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3986 - accuracy: 0.8579 - val_loss: 0.4326 - val_accuracy: 0.8464
# Epoch 10/40
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3955 - accuracy: 0.8592 - val_loss: 0.4334 - val_accuracy: 0.8471
# Epoch 11/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3905 - accuracy: 0.8601 - val_loss: 0.4300 - val_accuracy: 0.8461
# Epoch 12/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3872 - accuracy: 0.8612 - val_loss: 0.4283 - val_accuracy: 0.8488
# Epoch 13/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3843 - accuracy: 0.8627 - val_loss: 0.4338 - val_accuracy: 0.8489
# Epoch 14/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3793 - accuracy: 0.8638 - val_loss: 0.4361 - val_accuracy: 0.8431
# Epoch 15/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3782 - accuracy: 0.8634 - val_loss: 0.4335 - val_accuracy: 0.8472
# Epoch 16/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3738 - accuracy: 0.8657 - val_loss: 0.4312 - val_accuracy: 0.8428
# Epoch 17/40
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3698 - accuracy: 0.8676 - val_loss: 0.4226 - val_accuracy: 0.8532
# Epoch 18/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3703 - accuracy: 0.8663 - val_loss: 0.4300 - val_accuracy: 0.8459
# Epoch 19/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3697 - accuracy: 0.8664 - val_loss: 0.4324 - val_accuracy: 0.8460
# Epoch 20/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3631 - accuracy: 0.8698 - val_loss: 0.4167 - val_accuracy: 0.8529
# Epoch 21/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3616 - accuracy: 0.8700 - val_loss: 0.4359 - val_accuracy: 0.8455
# Epoch 22/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3605 - accuracy: 0.8702 - val_loss: 0.4239 - val_accuracy: 0.8474
# Epoch 23/40
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3613 - accuracy: 0.8688 - val_loss: 0.4294 - val_accuracy: 0.8473
# Epoch 24/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3596 - accuracy: 0.8699 - val_loss: 0.4252 - val_accuracy: 0.8482
# Epoch 25/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3564 - accuracy: 0.8716 - val_loss: 0.4508 - val_accuracy: 0.8411
# Epoch 26/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3575 - accuracy: 0.8706 - val_loss: 0.4269 - val_accuracy: 0.8491
# Epoch 27/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3546 - accuracy: 0.8703 - val_loss: 0.4202 - val_accuracy: 0.8509
# Epoch 28/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3524 - accuracy: 0.8716 - val_loss: 0.4294 - val_accuracy: 0.8476
# Epoch 29/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3514 - accuracy: 0.8739 - val_loss: 0.4279 - val_accuracy: 0.8483
# Epoch 30/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3503 - accuracy: 0.8738 - val_loss: 0.4273 - val_accuracy: 0.8506
# Epoch 31/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3487 - accuracy: 0.8739 - val_loss: 0.4373 - val_accuracy: 0.8417
# Epoch 32/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3490 - accuracy: 0.8735 - val_loss: 0.4299 - val_accuracy: 0.8534
# Epoch 33/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3481 - accuracy: 0.8748 - val_loss: 0.4243 - val_accuracy: 0.8500
# Epoch 34/40
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3469 - accuracy: 0.8744 - val_loss: 0.4426 - val_accuracy: 0.8510
# Epoch 35/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3451 - accuracy: 0.8769 - val_loss: 0.4445 - val_accuracy: 0.8440
# Epoch 36/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3434 - accuracy: 0.8754 - val_loss: 0.4353 - val_accuracy: 0.8506
# Epoch 37/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3426 - accuracy: 0.8756 - val_loss: 0.4290 - val_accuracy: 0.8523
# Epoch 38/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3415 - accuracy: 0.8766 - val_loss: 0.4297 - val_accuracy: 0.8483
# Epoch 39/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3422 - accuracy: 0.8766 - val_loss: 0.4185 - val_accuracy: 0.8527
# Epoch 40/40
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3388 - accuracy: 0.8774 - val_loss: 0.4312 - val_accuracy: 0.8502

# %%
print(test_labels)
# Out:
# [9 2 1 ... 8 1 5]

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
# Create a confusion matrix
from sklearn.metrics import confusion_matrix

# Make predictions
y_preds = model.predict(test_images)

# Create confusion matrix
# confusion_matrix(test_labels, tf.round(y_preds))

# %%
# Note: The following confusion matrix code is a remix of Scikit-Learn's 
# plot_confusion_matrix function - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_confusion_matrix.html
# and Made with ML's introductory notebook - https://github.com/GokuMohandas/MadeWithML/blob/main/notebooks/08_Neural_Networks.ipynb
import itertools
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15): 
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.

  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).
  
  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """  
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])
  
  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes), 
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)
  
  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
             horizontalalignment="center",
             color="white" if cm[i, j] > threshold else "black",
             size=text_size)

# %%
y_probs = model.predict(train_images) 
y_preds = y_probs.argmax(axis=1)
make_confusion_matrix(y_true=train_labels, 
                      y_pred=tf.round(y_preds),
                      classes=class_names,
                      figsize=(15, 15),
                      text_size=10)

# %%
import random

# Create a function for plotting a random image along with its prediction
def plot_random_image(model, images, true_labels, classes):
  """Picks a random image, plots it and labels it with a predicted and truth label.

  Args:
    model: a trained model (trained on data similar to what's in images).
    images: a set of random images (in tensor form).
    true_labels: array of ground truth labels for images.
    classes: array of class names for images.
  
  Returns:
    A plot of a random image from `images` with a predicted class label from `model`
    as well as the truth class label from `true_labels`.
  """ 
  # Setup random integer
  i = random.randint(0, len(images))
  
  # Create predictions and targets
  target_image = images[i]
  pred_probs = model.predict(target_image.reshape(1, 28, 28)) # have to reshape to get into right size for model
  pred_label = classes[pred_probs.argmax()]
  true_label = classes[true_labels[i]]

  # Plot the target image
  plt.imshow(target_image, cmap=plt.cm.binary)

  # Change the color of the titles depending on if the prediction is right or wrong
  if pred_label == true_label:
    color = "green"
  else:
    color = "red"

  # Add xlabel information (prediction/true label)
  plt.xlabel("Pred: {} {:2.0f}% (True: {})".format(pred_label,
                                                   100*tf.reduce_max(pred_probs),
                                                   true_label),
             color=color) # set the color to green or red

# %%
# Check out a random image as well as its prediction
plot_random_image(model=model, 
                  images=test_images, 
                  true_labels=test_labels, 
                  classes=class_names)
